# %% [markdown]
# # Ten-run alpha / memorization study
#
# Five AdamW and five **guarded** Muon runs. Run only the next cell to launch; no 80-run queue.

# %%
import sys
import subprocess
from pathlib import Path
CODE = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "run_study.py").is_file())
subprocess.run(["caffeinate", "-dimsu", sys.executable, str(CODE / "run_study.py"), "run"], cwd=CODE, check=True)
