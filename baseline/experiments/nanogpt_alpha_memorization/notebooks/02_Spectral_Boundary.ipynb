# %% [markdown]
# # Post-hoc WeightWatcher: AdamW vs Muon
#
# This notebook reads the saved 500-update checkpoints. WeightWatcher was not run during training. Alpha uses `fix_fingers='clip_xmax'`; error bars are across the five independent training seeds.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import display, Image, Markdown
if 'STUDY_ROOT' not in globals():
    STUDY_ROOT = Path('/tmp/nanogpt_alpha_memorization_latest.txt').read_text().strip()
ROOT = Path(STUDY_ROOT)
WW = ROOT / 'posthoc_weightwatcher'
if not WW.exists():
    raise RuntimeError('Run: python run_study.py spectra')
regimes = pd.read_csv(WW / 'alpha_regimes.csv')
summary = pd.read_csv(WW / 'alpha_summary.csv')
matrix = pd.read_csv(WW / 'alpha_matrix_summary.csv')
display(Markdown('## Did either optimizer enter alpha < 2 on the saved checkpoint grid?'))
display(regimes)
display(Markdown('## Across-seed alpha summary'))
display(summary)

# %%
for name in ['min_alpha_clip_xmax.png', 'mean_alpha_clip_xmax.png']:
    image = WW / 'figures' / name
    if image.exists(): display(Image(filename=str(image)))
display(Markdown('## Per-matrix alpha trajectories'))
for image in sorted((WW / 'figures').glob('matrix_*.png')):
    display(Image(filename=str(image)))
